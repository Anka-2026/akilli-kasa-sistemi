# %%
#ürünler

# %%
ürünler_sözlüğüm={"laptop":70000, "mouse":1250, "monitör":5500.99}

# %%
#kategoriler

# %%
kategoriler_sözlüğüm={"elektronik","aksesurar"}

# %%
#Müşteri Bilgisi ve İsim Maskeleme

# %%
müsteri_adı="Esra"

# %%
maskeli_isim = müsteri_adı[0] + "***"

# %%
#Sepet Oluşturma ve Hesaplama

# %%
maskeli_isim
# Out:
# 'E***'

# %%
sepet = [ürünler_sözlüğüm["laptop"], ürünler_sözlüğüm["mouse"]]

# %%
[ürünler_sözlüğüm["laptop"], ürünler_sözlüğüm["mouse"]]
# Out:
# [70000, 1250]

# %%
toplam_borc=sepet[0]+sepet[1]

# %%
toplam_borc
# Out:
# 71250

# %%
print("Müşteri:", maskeli_isim)
print("Toplam Ödenecek Tutar:", toplam_borc, "TL")
# Out:
# Müşteri: E***
# Toplam Ödenecek Tutar: 71250 TL
